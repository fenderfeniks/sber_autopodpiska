# %% [markdown]
# # Imports

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
#base
import pandas as pd
import numpy as np
from scipy import stats
# visual
import matplotlib.pyplot as plt
import seaborn as sns
#path
from pathlib import Path
import sys

# %%
#Config
PROJECT_ROOT = Path().resolve().parent
sys.path.insert(0, str(PROJECT_ROOT))
from src.config import load_config
cfg = load_config(PROJECT_ROOT / "configs" / "config.yaml")

#settings
RANDOM_STATE = cfg.data.random_state

#data_paths
TARGET_PATH = cfg.paths.raw_target_path(PROJECT_ROOT)
USERS_PATH = cfg.paths.raw_users_path(PROJECT_ROOT)

#src
sys.path.append(str(PROJECT_ROOT / cfg.paths.src_dir))

# %%
#src
from eda import full_eda_report, analyze_numeric, plot_distributions, plot_correlation_matrix, analyze_categorical, detect_outliers
from visual import setup_plotting
from database import get_engine, load_df_to_db, read_table, execute_query

# %%
#Matplotlib_Settings
# %matplotlib inline
setup_plotting()

# %% [markdown]
# # Data Loading

# %%
assert USERS_PATH.exists(), f'File not founded: {USERS_PATH}'
ga_sessions = pd.read_csv(USERS_PATH)
ga_sessions.head()
# Out:
# C:\Users\Максим\AppData\Local\Temp\ipykernel_720\995048080.py:2: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   ga_sessions = pd.read_csv(USERS_PATH)
#                                   session_id          client_id  visit_date  \
# 0  9055434745589932991.1637753792.1637753792  2108382700.163776  2021-11-24
# 1   905544597018549464.1636867290.1636867290   210838531.163687  2021-11-14
# 2  9055446045651783499.1640648526.1640648526  2108385331.164065  2021-12-28
# 3  9055447046360770272.1622255328.1622255328  2108385564.162225  2021-05-29
# 4  9055447046360770272.1622255345.1622255345  2108385564.162225  2021-05-29
#
#   visit_time  visit_number            utm_source utm_medium  \
# 0   14:36:32             1  ZpYIoDJMcFzVoPFsHGJL     banner
# 1   08:21:30             1  MvfHsxITijuriZxsqZqt        cpm
# 2   02:42:06             1  ZpYIoDJMcFzVoPFsHGJL     banner
# 3   05:00:00             1  kjsLglQLzykiRbcDiGcD        cpc
# 4   05:00:00             2  kjsLglQLzykiRbcDiGcD        cpc
#
#            utm_campaign         utm_adcontent           utm_keyword  \
# 0  LEoPHuyFvzoNfnzGgfcd  vCIpmpaGBnIQhyYNkXqp  puhZPIYqKXeFPaUviSjo
# 1  FTjNLDyTrXaWYgZymFkV  xhoenQgDQsgfEPYNPwKO  IGUCNvHlhfHpROGclCit
# 2  LEoPHuyFvzoNfnzGgfcd  vCIpmpaGBnIQhyYNkXqp  puhZPIYqKXeFPaUviSjo
# 3                   NaN  NOBKLgtuvqYWkXQHeYWM                   NaN
# 4                   NaN                   NaN                   NaN
#
#   device_category device_os device_brand device_model  \
# 0          mobile   Android       Huawei          NaN
# 1          mobile   Android      Samsung          NaN
# 2          mobile   Android       Huawei          NaN
# 3          mobile       NaN       Xiaomi          NaN
# 4          mobile       NaN       Xiaomi          NaN
#
#   device_screen_resolution    device_browser geo_country     geo_city
# 0                  360x720            Chrome      Russia     Zlatoust
# 1                  385x854  Samsung Internet      Russia       Moscow
# 2                  360x720            Chrome      Russia  Krasnoyarsk
# 3                  393x786            Chrome      Russia       Moscow
# 4                  393x786            Chrome      Russia       Moscow

# %%
assert TARGET_PATH.exists(), f'File not founded: {TARGET_PATH}'
ga_hits = pd.read_csv(TARGET_PATH)
ga_hits.head()
# Out:
#                                   session_id    hit_date  hit_time  \
# 0  5639623078712724064.1640254056.1640254056  2021-12-23  597864.0
# 1  7750352294969115059.1640271109.1640271109  2021-12-23  597331.0
# 2   885342191847998240.1640235807.1640235807  2021-12-23  796252.0
# 3   142526202120934167.1640211014.1640211014  2021-12-23  934292.0
# 4  3450086108837475701.1640265078.1640265078  2021-12-23  768741.0
#
#    hit_number hit_type hit_referer  \
# 0          30    event         NaN
# 1          41    event         NaN
# 2          49    event         NaN
# 3          46    event         NaN
# 4          79    event         NaN
#
#                                        hit_page_path event_category  \
# 0  sberauto.com/cars?utm_source_initial=google&ut...           quiz
# 1  sberauto.com/cars/fiat?city=1&city=18&rental_c...           quiz
# 2  sberauto.com/cars/all/volkswagen/polo/e994838f...           quiz
# 3  sberauto.com/cars?utm_source_initial=yandex&ut...           quiz
# 4  sberauto.com/cars/all/mercedes-benz/cla-klasse...           quiz
#
#   event_action event_label  event_value
# 0    quiz_show         NaN          NaN
# 1    quiz_show         NaN          NaN
# 2    quiz_show         NaN          NaN
# 3    quiz_show         NaN          NaN
# 4    quiz_show         NaN          NaN

# %%
ga_sessions.dtypes
# Out:
# session_id                  object
# client_id                   object
# visit_date                  object
# visit_time                  object
# visit_number                 int64
# utm_source                  object
# utm_medium                  object
# utm_campaign                object
# utm_adcontent               object
# utm_keyword                 object
# device_category             object
# device_os                   object
# device_brand                object
# device_model                object
# device_screen_resolution    object
# device_browser              object
# geo_country                 object
# geo_city                    object
# dtype: object

# %%
ga_hits.dtypes
# Out:
# session_id         object
# hit_date           object
# hit_time          float64
# hit_number          int64
# hit_type           object
# hit_referer        object
# hit_page_path      object
# event_category     object
# event_action       object
# event_label        object
# event_value       float64
# dtype: object

# %%
# Загрузить
load_df_to_db(ga_sessions, "ga_sessions")
load_df_to_db(ga_hits, "ga_hits")

# Читать
df = read_table("ga_sessions")

# Произвольный запрос
df = execute_query("SELECT * FROM ga_sessions WHERE visit_date > '2021-01-01'")
# Out:
# ga_sessions загружена
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[69], line 3
#       1 # Загрузить
#       2 load_df_to_db(ga_sessions, "ga_sessions")
# ----> 3 load_df_to_db(ga_hits, "ga_hits")
#       5 # Читать
#       6 df = read_table("ga_sessions")
#
# File ~\sber_autopodpiska\src\database.py:31, in load_df_to_db(df, table_name, if_exists)
#      29 def load_df_to_db(df: pd.DataFrame, table_name: str, if_exists: str = "replace"):
#      30     engine = get_engine()
# ---> 31     df.to_sql(table_name, engine, if_exists=if_exists, index=False)
#      32     print(f"{table_name} загружена")
#
# File C:\Anaconda\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File C:\Anaconda\Lib\site-packages\pandas\core\generic.py:3109, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2911 """
#    2912 Write records stored in a DataFrame to a SQL database.
#    2913
#    (...)   3105 [(1,), (None,), (2,)]
#    3106 """  # noqa: E501
#    3107 from pandas.io import sql
# -> 3109 return sql.to_sql(
#    3110     self,
#    3111     name,
#    3112     con,
#    3113     schema=schema,
#    3114     if_exists=if_exists,
#    3115     index=index,
#    3116     index_label=index_label,
#    3117     chunksize=chunksize,
#    3118     dtype=dtype,
#    3119     method=method,
#    3120 )
#
# File C:\Anaconda\Lib\site-packages\pandas\io\sql.py:844, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     839     raise NotImplementedError(
#     840         "'frame' argument should be either a Series or a DataFrame"
#     841     )
#     843 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
# --> 844     return pandas_sql.to_sql(
#     845         frame,
#     846         name,
#     847         if_exists=if_exists,
#     848         index=index,
#     849         index_label=index_label,
#     850         schema=schema,
#     851         chunksize=chunksize,
#     852         dtype=dtype,
#     853         method=method,
#     854         engine=engine,
#     855         **engine_kwargs,
#     856     )
#
# File C:\Anaconda\Lib\site-packages\pandas\io\sql.py:2030, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    2018 sql_engine = get_engine(engine)
#    2020 table = self.prep_table(
#    2021     frame=frame,
#    2022     name=name,
#    (...)   2027     dtype=dtype,
#    2028 )
# -> 2030 total_inserted = sql_engine.insert_records(
#    2031     table=table,
#    2032     con=self.con,
#    2033     frame=frame,
#    2034     name=name,
#    2035     index=index,
#    2036     schema=schema,
#    2037     chunksize=chunksize,
#    2038     method=method,
#    2039     **engine_kwargs,
#    2040 )
#    2042 self.check_case_sensitive(name=name, schema=schema)
#    2043 return total_inserted
#
# File C:\Anaconda\Lib\site-packages\pandas\io\sql.py:1570, in SQLAlchemyEngine.insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1567 from sqlalchemy import exc
#    1569 try:
# -> 1570     return table.insert(chunksize=chunksize, method=method)
#    1571 except exc.StatementError as err:
#    1572     # GH34431
#    1573     # https://stackoverflow.com/a/67358288/6067848
#    1574     msg = r"""(\(1054, "Unknown column 'inf(e0)?' in 'field list'"\))(?#
#    1575     )|inf can not be used with MySQL"""
#
# File C:\Anaconda\Lib\site-packages\pandas\io\sql.py:1121, in SQLTable.insert(self, chunksize, method)
#    1118     break
#    1120 chunk_iter = zip(*(arr[start_i:end_i] for arr in data_list))
# -> 1121 num_inserted = exec_insert(conn, keys, chunk_iter)
#    1122 # GH 46891
#    1123 if num_inserted is not None:
#
# File C:\Anaconda\Lib\site-packages\pandas\io\sql.py:1011, in SQLTable._execute_insert(self, conn, keys, data_iter)
#     999 def _execute_insert(self, conn, keys: list[str], data_iter) -> int:
#    1000     """
#    1001     Execute SQL statement inserting data
#    1002
#    (...)   1009        Each item contains a list of values to be inserted
#    1010     """
# -> 1011     data = [dict(zip(keys, row)) for row in data_iter]
#    1012     result = conn.execute(self.table.insert(), data)
#    1013     return result.rowcount
#
# KeyboardInterrupt:

# %% [markdown]
# # DF EDA

# %%
num_cols, cat_cols = full_eda_report(df)
# Out:
# ============================================================
# DATASET OVERVIEW
# ============================================================
# Shape: 1,860,042 rows x 18 columns
# Memory: 1691.21 MB
# Duplicates: 0 (0.00%)
#
# --- DATA TYPES ---
#   object: 17 columns
#   int64: 1 columns
#
# --- MISSING VALUES ---
#                  Count  Percent
# device_model   1843704    99.12
# utm_keyword    1082061    58.17
# device_os      1070138    57.53
# device_brand    367178    19.74
# utm_adcontent   335615    18.04
# utm_campaign    219603    11.81
# utm_source          97     0.01
#
# --- NUMERIC COLUMNS ---
#   1 columns: ['visit_number']
#
# --- CATEGORICAL COLUMNS ---
#   17 columns: ['session_id', 'client_id', 'visit_date', 'visit_time', 'utm_source', 'utm_medium', 'utm_campaign', 'utm_adcontent', 'utm_keyword', 'device_category', 'device_os', 'device_brand', 'device_model', 'device_screen_resolution', 'device_browser', 'geo_country', 'geo_city']

# %%
analyze_categorical(df)
# Out:
# ==================================================
# Column: session_id | Unique: 1860042 | Missing: 0
#   Too many categories (1860042), showing top 10:
# session_id
# 9055434745589932991.1637753792.1637753792    1
# 905544597018549464.1636867290.1636867290     1
# 9055446045651783499.1640648526.1640648526    1
# 9055447046360770272.1622255328.1622255328    1
# 9055447046360770272.1622255345.1622255345    1
# 9055447192389856083.1622453074.1622453074    1
# 9055455318486370642.1640843788.1640843788    1
# 9055461992850812764.1626107740.1626107740    1
# 9055462349345527315.1638536723.1638536723    1
# 9055466554104774132.1624800757.1624800757    1
#
# ==================================================
# Column: client_id | Unique: 1391717 | Missing: 0
#   Too many categories (1391717), showing top 10:
# client_id
# 1750498477.162945    462
# 130918396.162801     334
# 1266574870.162314    309
# 736859557.161956     306
# 1894772482.162186    276
# 1065181919.163161    271
# 1136708344.163342    257
# 1761941933.162184    254
# 260799907.1631       252
# 943676978.162189     248
#
# ==================================================
# Column: visit_date | Unique: 226 | Missing: 0
#   Too many categories (226), showing top 10:
# visit_date
# 2021-05-24    39453
# 2021-12-21    30704
# 2021-05-25    19305
# 2021-06-29    17367
# 2021-09-14    16204
# 2021-12-31    15910
# 2021-10-29    15818
# 2021-11-16    15253
# 2021-06-28    15169
# 2021-11-15    15009
#
# ==================================================
# Column: visit_time | Unique: 85318 | Missing: 0
#   Too many categories (85318), showing top 10:
# visit_time
# 12:00:00    61067
# 13:00:00    61002
# 10:00:00    60211
# 14:00:00    60178
# 11:00:00    59887
# 16:00:00    58854
# 15:00:00    57684
# 18:00:00    56575
# 19:00:00    55699
# 20:00:00    55520
#
# ==================================================
# Column: utm_source | Unique: 293 | Missing: 97
#   Too many categories (293), showing top 10:
# utm_source
# ZpYIoDJMcFzVoPFsHGJL    578290
# fDLlAcSmythWSCVMvqvL    300575
# kjsLglQLzykiRbcDiGcD    266354
# MvfHsxITijuriZxsqZqt    186199
# BHcvLfOaCWvWTykYqHVe    116320
# bByPQxmDaMXgpHeypKSM    102287
# QxAxdyPLuQMEcrdZWdWb     51415
# aXQzDWsJuGXeBXexNHjc     31152
# jaSOmLICuBzCFqHfBdRg     29241
# RmEBuqrriAfAVsLQQmhk     28055
#
# ==================================================
# Column: utm_medium | Unique: 56 | Missing: 0
#   Too many categories (56), showing top 10:
# utm_medium
# banner      552272
# cpc         434794
# (none)      300575
# cpm         242083
# referral    152050
# organic      63034
# email        29240
# push         28035
# stories      10582
# cpv           8022
#
# ==================================================
# Column: utm_campaign | Unique: 412 | Missing: 219603
#   Too many categories (412), showing top 10:
# utm_campaign
# LTuZkdKfxRGVceoWkVyg    463481
# LEoPHuyFvzoNfnzGgfcd    324044
# FTjNLDyTrXaWYgZymFkV    247360
# gecBYcKZCPMcVYdSSzKP    134042
# TmThBvoCcwkCZZUWACYq     26597
# XHNUiSKKGTEpSAlaVMFQ     24524
# okTXSMadDkjvntEHzIjp     24511
# SgIUDYUKnyWHVowUOqid     22841
# sbJRYgVfvcnqKJNDDYIr     20188
# LwJZxKuWmvOhPsaCeRjG     17615
#
# ==================================================
# Column: utm_adcontent | Unique: 286 | Missing: 335615
#   Too many categories (286), showing top 10:
# utm_adcontent
# JNHcPlZPxEMWDnRiyoBf    1006599
# vCIpmpaGBnIQhyYNkXqp     181048
# xhoenQgDQsgfEPYNPwKO     113072
# PkybGvWbaqORmxjNunqZ      60316
# LLfCasrxQzJIyuldcuWy      24222
# TuyPWsGQruPMpKvRxeBF      18189
# UxrnyMlRBSOhOjytXnMG      13583
# dUuXlWzvmhDSyclWRhNP      10280
# yYdBRbPmBMUZHXwqGxNx       9700
# WYLajZgbUhGimwBKDZUH       8610
#
# ==================================================
# Column: utm_keyword | Unique: 1219 | Missing: 1082061
#   Too many categories (1219), showing top 10:
# utm_keyword
# puhZPIYqKXeFPaUviSjo    506819
# aXQzDWsJuGXeBXexNHjc     24241
# pHqgLcdBQPSLcrTpLkdr     13767
# ITfrGJNwVsHBGJMAKoct     13353
# hAmNSZmQkKQKAjZEGlgb     11297
# UKNBOHebRIIsQRsjNKay     10946
# IGUCNvHlhfHpROGclCit      7568
# RkpOyeEPgcMBSDuHLQcj      6978
# JajANoFxoqXfKRNBUhzx      6758
# BmOOOIoWGHEfxEfoUezs      6602
#
# ==================================================
# Column: device_category | Unique: 3 | Missing: 0
# device_category
# mobile     79.3
# desktop    19.7
# tablet      1.0
#
# ==================================================
# Column: device_os | Unique: 13 | Missing: 1070138
# device_os
# Android          58.7
# iOS              26.2
# Windows          11.2
# Macintosh         3.1
# Linux             0.6
# (not set)         0.0
# Chrome OS         0.0
# BlackBerry        0.0
# Tizen             0.0
# Samsung           0.0
# Windows Phone     0.0
# Firefox OS        0.0
# Nokia             0.0
#
# ==================================================
# Column: device_brand | Unique: 205 | Missing: 367178
#   Too many categories (205), showing top 10:
# device_brand
# Apple        551088
# Samsung      332194
# Xiaomi       288367
# Huawei       185853
# Realme        19058
# (not set)     17545
# OPPO          13504
# Vivo          11740
# OnePlus        9965
# Asus           7929
#
# ==================================================
# Column: device_model | Unique: 104 | Missing: 1843704
#   Too many categories (104), showing top 10:
# device_model
# AuMdmADEIoPXiWpTsBEj    9778
# tWBQlsvNfHxRUjaPAfhd     653
# cwMJxNXiWUgMUxGiCTPs     651
# pTgAEPipQxDXCjPrJbHo     461
# FJApgTrMAGHoxCxQVKws     372
# tfPZFRbtlzEssBEesRwM     335
# pcvPxfVFaAmhwFmvIeYd     325
# aCLaTVQlHcXbUnQYQvIg     236
# mzJXHtJPIOSHoHtgezIA     235
# JAIKWwxRffFOXQcfGTVi     198
#
# ==================================================
# Column: device_screen_resolution | Unique: 5039 | Missing: 0
#   Too many categories (5039), showing top 10:
# device_screen_resolution
# 414x896      169090
# 1920x1080    125768
# 375x812      117944
# 393x851      115454
# 375x667       93341
# 360x780       92182
# 360x800       80547
# 412x915       74744
# 360x640       70588
# 390x844       60827
#
# ==================================================
# Column: device_browser | Unique: 57 | Missing: 0
#   Too many categories (57), showing top 10:
# device_browser
# Chrome              1013436
# Safari               478562
# YaBrowser            133311
# Safari (in-app)       69912
# Android Webview       55369
# Samsung Internet      47309
# Opera                 26817
# Firefox               16588
# Edge                  16065
# UC Browser              871
#
# ==================================================
# Column: geo_country | Unique: 166 | Missing: 0
#   Too many categories (166), showing top 10:
# geo_country
# Russia           1800565
# United States      11784
# Ukraine             9012
# Ireland             4034
# Belarus             3636
# Sweden              2694
# Kazakhstan          2279
# Germany             2232
# Turkey              1953
# Netherlands         1549
#
# ==================================================
# Column: geo_city | Unique: 2548 | Missing: 0
#   Too many categories (2548), showing top 10:
# geo_city
# Moscow              805329
# Saint Petersburg    296788
# (not set)            78172
# Yekaterinburg        35788
# Krasnodar            32243
# Kazan                29531
# Samara               24992
# Nizhny Novgorod      22227
# Ufa                  21679
# Novosibirsk          21568

# %% [markdown]
# ## ВЫВОДЫ:
#
# ### Типы данных:
# Все фичи являются типо object, однако имеются такие колонки как visit_date, visit_time которые могут/должны быть преобразованы в date, time соответственно. Device screen resolution можно распарсить в ширину и высоту а также площадь что бы
#
# ### Missing Valuse:
# - Device_model: 99.12% пропусков + закодирована => удаляем фичу
# - utm_keyword: ключевое слово 58.17% + закодирована => восстановить невозможно, но есть доминирующее ключевое слово, можно сделать фичу является ли ключевое слово доминантным или нет(пропуски = нет)
# - device_os: 57.53% пропусков, есть 2 варианта заполнения т.к. есть 3 доминирующих операционных системы можно заполнить с сохранением пропорции, но более чистый вариант будет либо удалить, либо заполнить (not set)
# - device_brand: 19,74% пропусков, нет ярко выраженного доминантного производителя, заполню (not set)
# - utm_adcontent: 18.04% пропусков + закодирована, есть доминантный представитель, можно заполнить им, либо ввести новую категорию (not set) + 286 уникальных категорий из которых большую половину занимает 1 категорию, можно добавить фичу принадлежит ли данной фиче
# - utm_campaign: 11.81% + закодирована: нет доминирующей категории => либо распределить в соответствии с пропорциями первых 4 т.к. они в сумме дают высокий процент по фиче либо удалить эти объекты
# - utm_source: 0.01% + закодирована: либо удалить объекты либо попробовать восстановить из других закодированных фич где совпадения такие же как и в пропусках(например utm_medium + utm_campaign)
#
# ### Наличие доминантных категорий
# - utm_adcontent
# - utm_keyword
# - device_os(android+ iOS+ Windows)

# %% [markdown]
# ## Additional EDA

# %%
df['visit_date'] = pd.to_datetime(df['visit_date'])

# %%
df['visit_year'] = df['visit_date'].dt.year

# %%
df['visit_year'].nunique()
# Out:
# 1

# %%
df['visit_month'] = df['visit_date'].dt.month

# %%
df['visit_month'].value_counts()
# Out:
# visit_month
# 12    399102
# 11    297769
# 10    281622
# 9     257478
# 7     185244
# 6     166470
# 8     164155
# 5     108202
# Name: count, dtype: int64

# %%
df['visit_day'] = df['visit_date'].dt.day

# %%
df['visit_day'].value_counts()
# Out:
# visit_day
# 24    95389
# 29    81773
# 21    79686
# 30    75252
# 25    74264
# 14    67288
# 28    65109
# 26    61875
# 15    60651
# 16    60122
# 17    59849
# 22    59584
# 13    59180
# 27    59160
# 23    59034
# 12    58739
# 18    57918
# 19    57632
# 11    56670
# 6     54215
# 20    53857
# 10    53759
# 7     52827
# 8     52214
# 1     52121
# 5     51883
# 9     51856
# 2     49107
# 3     48621
# 4     45360
# 31    45047
# Name: count, dtype: int64

# %%
df['visit_dayofweek'] = df['visit_date'].dt.dayofweek

# %%
df['visit_dayofweek'].value_counts()
# Out:
# visit_dayofweek
# 1    305130
# 0    300906
# 3    274462
# 4    268819
# 2    258616
# 5    226397
# 6    225712
# Name: count, dtype: int64

# %%
df['visit_time'] = pd.to_datetime(df["visit_time"], format="%H:%M:%S")

# %%
df['visit_hour'] = df['visit_time'].dt.hour

# %%
df['visit_hour'].value_counts()
# Out:
# visit_hour
# 14    111487
# 16    105241
# 15    103854
# 18    102701
# 13    102477
# 12    102071
# 11    101266
# 17    101086
# 10    100849
# 19     99184
# 20     98731
# 21     97612
# 22     93473
# 9      91860
# 23     84643
# 8      72015
# 0      66202
# 7      54894
# 1      40080
# 6      36440
# 2      27328
# 5      25292
# 3      21036
# 4      20220
# Name: count, dtype: int64

# %%
df['visit_minute'] = df['visit_time'].dt.minute

# %%
df["visit_datetime"] = pd.to_datetime(
    df["visit_date"].astype(str) + " " + df["visit_time"].apply(lambda x: str(x).split(" ")[-1]),
    format="%Y-%m-%d %H:%M:%S"
)

# %% [markdown]
# # EDA Target

# %%
num_cols, cat_cols = full_eda_report(targets)
# Out:
# ============================================================
# DATASET OVERVIEW
# ============================================================
# Shape: 15,726,470 rows x 11 columns
# Memory: 9924.31 MB
# Duplicates: 0 (0.00%)
#
# --- DATA TYPES ---
#   object: 8 columns
#   float64: 2 columns
#   int64: 1 columns
#
# --- MISSING VALUES ---
#                 Count  Percent
# event_value  15726470   100.00
# hit_time      9160322    58.25
# hit_referer   6274804    39.90
# event_label   3760184    23.91
#
# --- NUMERIC COLUMNS ---
#   3 columns: ['hit_time', 'hit_number', 'event_value']
#
# --- CATEGORICAL COLUMNS ---
#   8 columns: ['session_id', 'hit_date', 'hit_type', 'hit_referer', 'hit_page_path', 'event_category', 'event_action', 'event_label']

# %%
analyze_categorical(targets)
# Out:
# ==================================================
# Column: session_id | Unique: 1734610 | Missing: 0
#   Too many categories (1734610), showing top 10:
# session_id
# 5442565791571325612.1632449195.1632449195    768
# 6568868914238486437.1632270313.1632270313    678
# 5959671972744778783.1632490527.1632490600    548
# 7452598043578978502.1632358598.1632358598    514
# 3070792010704358528.1629752408.1629752408    498
# 8115026869866033734.1629319807.1629319807    496
# 3740600179229362264.1639614533.1639614533    496
# 686125592720823356.1634587719.1634587719     496
# 6841198707279638061.1631825458.1631825458    496
# 1191055000444557028.1634948839.1634948839    492
#
# ==================================================
# Column: hit_date | Unique: 226 | Missing: 0
#   Too many categories (226), showing top 10:
# hit_date
# 2021-05-24    513035
# 2021-12-21    280192
# 2021-05-25    235805
# 2021-09-23    168899
# 2021-05-26    158382
# 2021-09-24    153241
# 2021-06-29    152641
# 2021-09-14    143624
# 2021-06-28    134588
# 2021-09-22    133147
#
# ==================================================
# Column: hit_type | Unique: 1 | Missing: 0
# hit_type
# event    100.0
#
# ==================================================
# Column: hit_referer | Unique: 37873 | Missing: 6274804
#   Too many categories (37873), showing top 10:
# hit_referer
# HbolMJUevblAbkHClEQa    8879187
# FwdMTcXzWAwhtsnMAbhS      91940
# sAGDBCdeVPmQPwkVEcIX      53565
# GQmOLxANuSeCxCanBpMl      35470
# ZeRnFrHdnMmnqraghdGJ      23016
# CENJYQocGncDfpQMoNnT      16787
# NfSAiKHBqffzsXrbjcSr      14949
# trXmoxcphNjuYcShOXwL      10325
# eAbATQERmGPolIKkWXkU       8231
# VgVmpaHvXKWLyZgGPCUk       6326
#
# ==================================================
# Column: hit_page_path | Unique: 342715 | Missing: 0
#   Too many categories (342715), showing top 10:
# hit_page_path
# podpiska.sberauto.com/                                                                                                                                                                                                  2793639
# sberauto.com/cars?city=1&rental_page=rental_only&rental_car=rental_only&city=18                                                                                                                                         1103484
# sberauto.com/cars?utm_source_initial=sbol&utm_medium_initial=banner&utm_campaign_initial=LEoPHuyFvzoNfnzGgfcd&utm_content_initial=vCIpmpaGBnIQhyYNkXqp&city=1&rental_page=rental_only&rental_car=rental_only&city=18     754215
# sberauto.com/cars/f28947a1?rental_page=rental_car                                                                                                                                                                        264878
# sberauto.com/cars/bf24b977?rental_page=rental_car                                                                                                                                                                        263966
# sberauto.com/cars?utm_source_initial=sbol&utm_medium_initial=banner&utm_campaign_initial=LEoPHuyFvzoNfnzGgfcd&city=1&rental_page=rental_only&rental_car=rental_only&city=18                                              257588
# sberauto.com/cars?city=1&city=18&rental_page=rental_only&rental_car=rental_only&page=1                                                                                                                                   199098
# sberauto.com/cars/bfc21661?rental_page=rental_car                                                                                                                                                                        187602
# sberauto.com/cars/2fc745ed?rental_page=rental_car                                                                                                                                                                        168387
# sberauto.com/cars/all/skoda/rapid/bf24b977?rental_page=rental_car                                                                                                                                                        168352
#
# ==================================================
# Column: event_category | Unique: 52 | Missing: 0
#   Too many categories (52), showing top 10:
# event_category
# card_web            7456998
# search_form         2423605
# sub_page_view       1986074
# sub_button_click    1073471
# listing_ads         1040468
# cars                 358915
# sap_search_form      356596
# quiz                 263134
# auth                 189373
# sap_search__form     188129
#
# ==================================================
# Column: event_action | Unique: 230 | Missing: 0
#   Too many categories (230), showing top 10:
# event_action
# view_card                  3558985
# view_new_card              3551009
# sub_landing                1798117
# go_to_car_card              973666
# sub_view_cars_click         791515
# search_form_region          512069
# search_form_search_btn      433748
# sap_search_form_cost_to     356596
# showed_number_ads           326274
# pagination_click            248944
#
# ==================================================
# Column: event_label | Unique: 39825 | Missing: 3760184
#   Too many categories (39825), showing top 10:
# event_label
# KclpemfoHstknWHFiLit    6505447
# hAHqGICPFQiPwtzubOzs    1284914
# OHfyUfDKdPgBdvelDlfG     626554
# pzAKUYdRKNEUXxxBFUPX     358915
# ghOrjqpgskpGHSFfBBsi     342500
# vodKSlUobUWTVlgsJqdI     164800
# MbQsNZxBQkusqOKQZfWz      91248
# yatapsJsSVhXEatMiuad      87587
# exyNyRcKbRJNDavyEYoX      86305
# qshvwcBdvHYvKYaJhTMu      81837

# %%
target_action = [
    'sub_car_claim_click',
    'sub_car_claim_submit_click', 
    'sub_open_dialog_click',
    'sub_custom_question_submit_click',
    'sub_call_number_click',
    'sub_callback_submit_click',
    'sub_submit_success',
    'sub_car_request_submit_click'
]
