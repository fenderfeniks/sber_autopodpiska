# %% [markdown]
# # Imports

# %%
import pandas as pd
import dill
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import roc_auc_score

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer

from sklearn.dummy import DummyClassifier

# %% [markdown]
# # Ga_Sessions

# %% [markdown]
# ## Data Preparation

# %% [markdown]
# ### Data loading

# %%
df = pd.read_csv('data/ga_sessions.csv')
df.head()
# Out:
# C:\Users\Максим\AppData\Local\Temp\ipykernel_4456\2960945628.py:1: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('data/ga_sessions.csv')
#                                   session_id          client_id  visit_date  \
# 0  9055434745589932991.1637753792.1637753792  2108382700.163776  2021-11-24
# 1   905544597018549464.1636867290.1636867290   210838531.163687  2021-11-14
# 2  9055446045651783499.1640648526.1640648526  2108385331.164065  2021-12-28
# 3  9055447046360770272.1622255328.1622255328  2108385564.162225  2021-05-29
# 4  9055447046360770272.1622255345.1622255345  2108385564.162225  2021-05-29
#
#   visit_time  visit_number            utm_source utm_medium  \
# 0   14:36:32             1  ZpYIoDJMcFzVoPFsHGJL     banner
# 1   08:21:30             1  MvfHsxITijuriZxsqZqt        cpm
# 2   02:42:06             1  ZpYIoDJMcFzVoPFsHGJL     banner
# 3   05:00:00             1  kjsLglQLzykiRbcDiGcD        cpc
# ...

# %%
df.shape
# Out:
# (1860042, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1860042 entries, 0 to 1860041
# Data columns (total 18 columns):
#  #   Column                    Dtype
# ---  ------                    -----
#  0   session_id                object
#  1   client_id                 object
#  2   visit_date                object
#  3   visit_time                object
#  4   visit_number              int64
#  5   utm_source                object
#  6   utm_medium                object
#  7   utm_campaign              object
#  8   utm_adcontent             object
#  9   utm_keyword               object
#  10  device_category           object
#  11  device_os                 object
#  12  device_brand              object
#  13  device_model              object
#  14  device_screen_resolution  object
#  15  device_browser            object
#  16  geo_country               object
#  17  geo_city                  object
# dtypes: int64(1), object(17)
# memory usage: 255.4+ MB

# %%
df.describe()
# Out:
#        visit_number
# count  1.860042e+06
# mean   2.712804e+00
# std    1.182907e+01
# min    1.000000e+00
# 25%    1.000000e+00
# 50%    1.000000e+00
# 75%    2.000000e+00
# max    5.640000e+02

# %%
df.visit_number.max()
# Out:
# 564

# %%
df.isnull().sum()
# Out:
# session_id                        0
# client_id                         0
# visit_date                        0
# visit_time                        0
# visit_number                      0
# utm_source                       97
# utm_medium                        0
# utm_campaign                 219603
# utm_adcontent                335615
# utm_keyword                 1082061
# device_category                   0
# device_os                   1070138
# device_brand                 367178
# device_model                1843704
# device_screen_resolution          0
# device_browser                    0
# geo_country                       0
# geo_city                          0
# dtype: int64

# %% [markdown]
# ### Change Types

# %%
df['visit_date'] = pd.to_datetime(df['visit_date'])
df['visit_time'] = pd.to_datetime(df['visit_time'], format='%H:%M:%S').dt.time

# %% [markdown]
# ### Fill null

# %%
(df.isnull().sum() / len(df) * 100).round(1)
# Out:
# session_id                   0.0
# client_id                    0.0
# visit_date                   0.0
# visit_time                   0.0
# visit_number                 0.0
# utm_source                   0.0
# utm_medium                   0.0
# utm_campaign                11.8
# utm_adcontent               18.0
# utm_keyword                 58.2
# device_category              0.0
# device_os                   57.5
# device_brand                19.7
# device_model                99.1
# device_screen_resolution     0.0
# device_browser               0.0
# geo_country                  0.0
# geo_city                     0.0
# dtype: float64

# %% [markdown]
# #### UTM Block

# %%
df[df.utm_source.isnull()]
# Out:
#                                         session_id             client_id  \
# 77652    1100240274910044288.1640728207.1640728207      256169651.163731
# 122841   1303431342277938317.1637250145.1637250145  303478758.1637239949
# 136220   1364914954463538089.1637595059.1637595059       317794027.16344
# 136221   1364914954463538089.1638478637.1638478637       317794027.16344
# 139706   1380043242326371104.1637518268.1637518268      321316356.163648
# ...                                            ...                   ...
# 1629120  8025307339522195714.1638678933.1638678933     1868537473.163671
# 1629121  8025307339522195714.1638688249.1638688249     1868537473.163671
# 1629122  8025307339522195714.1638954236.1638954236     1868537473.163671
# 1732460   848873006059532776.1637459623.1637459623       197643648.16374
# 1772156  8663363699581084869.1636806863.1636806863     2017096546.163652
#
#         visit_date visit_time  visit_number utm_source    utm_medium  \
# ...

# %%
df[df.utm_campaign == 'LTuZkdKfxRGVceoWkVyg']
# Out:
#                                         session_id          client_id  \
# 5        9055447192389856083.1622453074.1622453074  2108385598.162245
# 11       9055469620715506713.1628883994.1628883994  2108390820.162888
# 12       9055469620715506713.1633110583.1633110583  2108390820.162888
# 13       9055469620715506713.1635878177.1635878177  2108390820.162888
# 28       9055505230298952295.1638478433.1638478433  2108399111.163848
# ...                                            ...                ...
# 1860026  9055355469082180480.1636350848.1636350848  2108364242.163635
# 1860029  9055376699099939975.1630766214.1630766214  2108369185.163077
# 1860032  9055394269810294140.1629912447.1629912447  2108373276.162991
# 1860038  9055421130527858185.1622007305.1622007305  2108379530.162201
# 1860039  9055422955903931195.1636979515.1636979515  2108379955.163697
#
#         visit_date visit_time  visit_number            utm_source utm_medium  \
# ...

# %% [markdown]
# Делаю вывод что utm_source, utm_medium, utm_campaign, utm_adcontent, utm_keyowrd имеют связь и их можно заполнить с помощью этой связи

# %%
df[['utm_source', 'utm_medium', 'utm_campaign', 'utm_keyword']].dropna().head(20)
# Out:
#               utm_source utm_medium          utm_campaign  \
# 0   ZpYIoDJMcFzVoPFsHGJL     banner  LEoPHuyFvzoNfnzGgfcd
# 1   MvfHsxITijuriZxsqZqt        cpm  FTjNLDyTrXaWYgZymFkV
# 2   ZpYIoDJMcFzVoPFsHGJL     banner  LEoPHuyFvzoNfnzGgfcd
# 6   TxKUcPpthBDPieTGmVhx        cpc  FTjNLDyTrXaWYgZymFkV
# 8   ZpYIoDJMcFzVoPFsHGJL     banner  LEoPHuyFvzoNfnzGgfcd
# 13  gVRrcxiDQubJiljoTbGm   referral  LTuZkdKfxRGVceoWkVyg
# 16  ZpYIoDJMcFzVoPFsHGJL     banner  LEoPHuyFvzoNfnzGgfcd
# 18  ZpYIoDJMcFzVoPFsHGJL     banner  gecBYcKZCPMcVYdSSzKP
# 19  ZpYIoDJMcFzVoPFsHGJL     banner  LEoPHuyFvzoNfnzGgfcd
# 28  fDLlAcSmythWSCVMvqvL     (none)  LTuZkdKfxRGVceoWkVyg
# 31  ZpYIoDJMcFzVoPFsHGJL     banner  LEoPHuyFvzoNfnzGgfcd
# 36  ZpYIoDJMcFzVoPFsHGJL     banner  LEoPHuyFvzoNfnzGgfcd
# 37  kjsLglQLzykiRbcDiGcD        cpc  LwJZxKuWmvOhPsaCeRjG
# 39  kjsLglQLzykiRbcDiGcD        cpc  LwJZxKuWmvOhPsaCeRjG
# 40  kjsLglQLzykiRbcDiGcD        cpc  LwJZxKuWmvOhPsaCeRjG
# ...

# %%
df[df['utm_keyword'].isnull()][['utm_source', 'utm_medium']].value_counts().head(10)
# Out:
# utm_source            utm_medium
# fDLlAcSmythWSCVMvqvL  (none)        232055
# ZpYIoDJMcFzVoPFsHGJL  banner        228504
# kjsLglQLzykiRbcDiGcD  cpc           158861
# MvfHsxITijuriZxsqZqt  cpm            77358
# bByPQxmDaMXgpHeypKSM  referral       76033
# BHcvLfOaCWvWTykYqHVe  cpc            74224
# QxAxdyPLuQMEcrdZWdWb  cpc            26817
# aXQzDWsJuGXeBXexNHjc  referral       24435
# kjsLglQLzykiRbcDiGcD  organic        24424
# RmEBuqrriAfAVsLQQmhk  cpc            21427
# Name: count, dtype: int64

# %% [markdown]
# Заполняю utm_keyword значением not set т.к. имеет смысл в источниках трафика отсутствие ключевых слов как факт

# %%
df['utm_keyword'] = df['utm_keyword'].fillna('not_set')

# %%
df[df['utm_campaign'].isnull()][['utm_source', 'utm_medium']].value_counts().head(10)
# Out:
# utm_source            utm_medium
# BHcvLfOaCWvWTykYqHVe  cpc           110479
# kjsLglQLzykiRbcDiGcD  cpc            86919
# QxAxdyPLuQMEcrdZWdWb  cpc             7725
# SzZERoLMmrEUEhDaYcyN  cpc             6828
# bByPQxmDaMXgpHeypKSM  referral        5615
# ISrKoXQCxqqYvAZICvjs  smm             1675
# iNFgfQPqHPBuvGCYtrQE  smm              242
# QxAxdyPLuQMEcrdZWdWb  smm               68
# GmILPdZyuAVJCPsUBHeN  cpc               30
# jaSOmLICuBzCFqHfBdRg  email             20
# Name: count, dtype: int64

# %%
df['utm_campaign'] = df['utm_campaign'].fillna('not_set')

# %%
df['utm_adcontent'] = df['utm_adcontent'].fillna('not_set')

# %% [markdown]
# Так как все показатели зашифрованы было принято решение заполнить их значением not_set т.к. предположительно в большинстве случаев это так и должно быть

# %%
(df.isnull().sum() / len(df) * 100).round(1)
# Out:
# session_id                   0.0
# client_id                    0.0
# visit_date                   0.0
# visit_time                   0.0
# visit_number                 0.0
# utm_source                   0.0
# utm_medium                   0.0
# utm_campaign                 0.0
# utm_adcontent                0.0
# utm_keyword                  0.0
# device_category              0.0
# device_os                   57.5
# device_brand                19.7
# device_model                99.1
# device_screen_resolution     0.0
# device_browser               0.0
# geo_country                  0.0
# geo_city                     0.0
# dtype: float64

# %% [markdown]
# #### Device Block

# %%
df[df['device_os'].isnull()]['device_category'].value_counts()
# Out:
# device_category
# mobile     810281
# desktop    248223
# tablet      11634
# Name: count, dtype: int64

# %%
df[df['device_category'] == 'mobile']['device_os'].value_counts().head(10)
# Out:
# device_os
# Android          459192
# iOS              205256
# Linux                50
# BlackBerry           27
# (not set)            20
# Windows              16
# Macintosh            10
# Tizen                 5
# Samsung               4
# Windows Phone         4
# Name: count, dtype: int64

# %%
df.groupby('device_category')['device_os'].apply(lambda x: x.isnull().mean() * 100).round(1)
# Out:
# device_category
# desktop    67.7
# mobile     54.9
# tablet     63.5
# Name: device_os, dtype: float64

# %% [markdown]
# Создаю словарь где в ключе будет device_category+device_brand а в значении device_os

# %%
os_map = df[df['device_os'].notna()].groupby(['device_category', 'device_brand'])['device_os'].agg(lambda x: x.mode()[0])

# %%
df['device_os'] = df.apply(
    lambda row: os_map.get((row['device_category'], row['device_brand']), 'not_set') 
    if pd.isna(row['device_os']) else row['device_os'], axis=1
)

# %%
df['device_os'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['device_os'].nunique()
# Out:
# 14

# %%
(df.isnull().sum() / len(df) * 100).round(1)
# Out:
# session_id                   0.0
# client_id                    0.0
# visit_date                   0.0
# visit_time                   0.0
# visit_number                 0.0
# utm_source                   0.0
# utm_medium                   0.0
# utm_campaign                 0.0
# utm_adcontent                0.0
# utm_keyword                  0.0
# device_category              0.0
# device_os                    0.0
# device_brand                19.7
# device_model                99.1
# device_screen_resolution     0.0
# device_browser               0.0
# geo_country                  0.0
# geo_city                     0.0
# dtype: float64

# %% [markdown]
# Планриую заполнить Device brand модой для каждой device_category, а колонку device_model удалить

# %%
df.groupby('device_category')['device_brand'].nunique()
# Out:
# device_category
# desktop     14
# mobile     174
# tablet      73
# Name: device_brand, dtype: int64

# %%
df.groupby('device_category')['device_brand'].apply(
    lambda x: f"{x.mode()[0]} ({x.value_counts().iloc[0]/len(x)*100:.1f}%)"
)
# Out:
# device_category
# desktop     Apple (0.0%)
# mobile     Apple (36.9%)
# tablet     Apple (34.0%)
# Name: device_brand, dtype: object

# %%
df[(df['device_brand'].isnull()) & (df['device_category'] == 'mobile')]
# Out:
#                                         session_id          client_id  \
# 24009    9161436681631382037.1625242134.1625242134  2133063199.162524
# 26043    9170117347413292512.1631024608.1631024608  2135084324.163102
# 26714    9172914908724584214.1634328343.1634328343  2135735682.163433
# 43029     944703987097397663.1624631711.1624631711   219956037.162463
# 60248    1021042336384541670.1624630248.1624630248   237729944.162463
# ...                                            ...                ...
# 1840226  8966694021090161968.1622324530.1622324530  2087721140.162232
# 1840227  8966694021090161968.1622366233.1622366233  2087721140.162232
# 1853240  9024892064901457390.1622238706.1622238706  2101271428.162224
# 1854416  9030278666862206423.1629925388.1629925388  2102525594.162923
# 1855177  9034071303375097594.1631129344.1631129344  2103408636.163113
#
#         visit_date visit_time  visit_number            utm_source utm_medium  \
# ...

# %% [markdown]
# Т.к. нет доминантной моды принимаю решение заполнить device_brand значением not_set

# %%
df['device_brand'] = df['device_brand'].fillna('not_set')
df = df.drop(columns=['device_model'])

# %%
df.isnull().sum()
# Out:
# session_id                   0
# client_id                    0
# visit_date                   0
# visit_time                   0
# visit_number                 0
# utm_source                  97
# utm_medium                   0
# utm_campaign                 0
# utm_adcontent                0
# utm_keyword                  0
# device_category              0
# device_os                    0
# device_brand                 0
# device_screen_resolution     0
# device_browser               0
# geo_country                  0
# geo_city                     0
# dtype: int64

# %%
df['utm_source'] = df.utm_source.fillna('not_set')

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Dublicates

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['session_id'].duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Дубликатов не обнаружено

# %% [markdown]
# ### outliers

# %%
df.select_dtypes(include='number').columns
# Out:
# Index(['visit_number'], dtype='object')

# %%
df.visit_number.describe()
# Out:
# count    1.860042e+06
# mean     2.712804e+00
# std      1.182907e+01
# min      1.000000e+00
# 25%      1.000000e+00
# 50%      1.000000e+00
# 75%      2.000000e+00
# max      5.640000e+02
# Name: visit_number, dtype: float64

# %%
df['visit_number'].quantile([0.95, 0.99, 0.999])
# Out:
# 0.950      6.0
# 0.990     32.0
# 0.999    189.0
# Name: visit_number, dtype: float64

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

# До обрезки
axes[0].boxplot(df['visit_number'])
axes[0].set_title('visit_number — все значения')

# Посмотрим без экстремальных выбросов
axes[1].boxplot(df[df['visit_number'] <= 50]['visit_number'])
axes[1].set_title('visit_number — до 50')

plt.tight_layout()
plt.show()

# %%
q_25_vn = df.visit_number.quantile(0.25)
q_75_vn = df.visit_number.quantile(0.75)
iqr = q_75_vn - q_25_vn
boundaries = (q_25_vn - 1.5 * iqr, q_75_vn + 1.5 * iqr)
df.visit_number = df.visit_number.clip(upper=boundaries[1], lower=boundaries[0])

# %%
df.visit_number.describe()
# Out:
# count    1.860042e+06
# mean     1.438277e+00
# std      8.185243e-01
# min      1.000000e+00
# 25%      1.000000e+00
# 50%      1.000000e+00
# 75%      2.000000e+00
# max      3.500000e+00
# Name: visit_number, dtype: float64

# %% [markdown]
# # Ga_hits

# %% [markdown]
# ## Data Preparation

# %% [markdown]
# ### Data Load

# %%
df_hits_sample = pd.read_csv('data/ga_hits-003.csv', nrows=5)
df_hits_sample.columns.tolist()
# Out:
# ['session_id',
#  'hit_date',
#  'hit_time',
#  'hit_number',
#  'hit_type',
#  'hit_referer',
#  'hit_page_path',
#  'event_category',
#  'event_action',
#  'event_label',
#  'event_value']

# %%
df_hits_sample = pd.read_csv('data/ga_hits-003.csv', nrows=10000)
df_hits_sample['event_action'].value_counts().head(20)
# Out:
# event_action
# view_card                             2802
# view_new_card                         2192
# sub_landing                           1814
# sub_view_cars_click                    609
# go_to_car_card                         351
# showed_number_ads                      237
# search_form_search_btn                 187
# search_form_region                     167
# pagination_click                       161
# photos_all                             147
# sap_search_form_cost_to                141
# view_more_click                        107
# search_form_mark_select                 97
# search_form_model_select                92
# search_form_search_car_type_select      58
# sap_search_form_cost_from               54
# photos                                  54
# quiz_show                               52
# sub_header_link_click                   37
# search_kpp                              35
# Name: count, dtype: int64

# %%
target_actions = [
    'sub_car_claim_click',
    'sub_car_claim_submit_click', 
    'sub_open_dialog_click',
    'sub_custom_question_submit_click',
    'sub_call_number_click',
    'sub_callback_submit_click',
    'sub_submit_success',
    'sub_car_request_submit_click'
]

chunks = []
for chunk in pd.read_csv('data/ga_hits-003.csv', chunksize=100_000):
    filtered = chunk[chunk['event_action'].isin(target_actions)][['session_id', 'event_action']]
    chunks.append(filtered)

df_hits = pd.concat(chunks, ignore_index=True)

# %%
df_hits['target'] = 1

target = df_hits.groupby('session_id')['target'].max().reset_index()

# %%
target.nunique()
# Out:
# session_id    50760
# target            1
# dtype: int64

# %% [markdown]
# # Merge

# %%
df = df.merge(target, on='session_id', how='left')
df['target'] = df['target'].fillna(0).astype(int)

# %%
df.head()
# Out:
#                                   session_id          client_id visit_date  \
# 0  9055434745589932991.1637753792.1637753792  2108382700.163776 2021-11-24
# 1   905544597018549464.1636867290.1636867290   210838531.163687 2021-11-14
# 2  9055446045651783499.1640648526.1640648526  2108385331.164065 2021-12-28
# 3  9055447046360770272.1622255328.1622255328  2108385564.162225 2021-05-29
# 4  9055447046360770272.1622255345.1622255345  2108385564.162225 2021-05-29
#
#   visit_time  visit_number            utm_source utm_medium  \
# 0   14:36:32           1.0  ZpYIoDJMcFzVoPFsHGJL     banner
# 1   08:21:30           1.0  MvfHsxITijuriZxsqZqt        cpm
# 2   02:42:06           1.0  ZpYIoDJMcFzVoPFsHGJL     banner
# 3   05:00:00           1.0  kjsLglQLzykiRbcDiGcD        cpc
# 4   05:00:00           2.0  kjsLglQLzykiRbcDiGcD        cpc
#
#            utm_campaign         utm_adcontent           utm_keyword  \
# 0  LEoPHuyFvzoNfnzGgfcd  vCIpmpaGBnIQhyYNkXqp  puhZPIYqKXeFPaUviSjo
# ...

# %%
df.target.unique()
# Out:
# array([0, 1])

# %% [markdown]
# ### Correlation

# %%
df.select_dtypes('object').nunique().sort_values()
# Out:
# device_category                   3
# device_os                        14
# utm_medium                       56
# device_browser                   57
# geo_country                     166
# device_brand                    206
# utm_adcontent                   287
# utm_source                      294
# utm_campaign                    413
# utm_keyword                    1220
# geo_city                       2548
# device_screen_resolution       5039
# visit_time                    85318
# client_id                   1391717
# session_id                  1860042
# dtype: int64

# %%
cols_for_heatmap = ['device_category', 'device_os', 'visit_number', 'target']

df_corr = pd.get_dummies(df[cols_for_heatmap])

plt.figure(figsize=(12, 8))
sns.heatmap(df_corr.corr(), annot=True, fmt='.2f', cmap='coolwarm')
plt.show()

# %% [markdown]
# Корреляция признаков с целевым действием слабая (max ~0.04 у visit_number). Это говорит об отсутствии линейной зависимости, что ожидаемо для задачи предсказания поведения пользователя. Обнаружена сильная мультиколлинеарность между категориями устройств (desktop/mobile: -0.97) и между OS и категорией устройства (iOS/mobile: 0.66), что необходимо учитывать при отборе признаков для модели.

# %%
df.groupby('device_category')['target'].mean()
# Out:
# device_category
# desktop    0.031382
# mobile     0.026022
# tablet     0.023050
# Name: target, dtype: float64

# %% [markdown]
# CR по категориям устройств: desktop 3.1%, mobile 2.6%, tablet 2.3%. Категории достаточно различаются, объединение нецелесообразно.

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 4))

df['device_category'].value_counts().plot(kind='bar', ax=axes[0], title='Device Category')
df['utm_medium'].value_counts().head(10).plot(kind='bar', ax=axes[1], title='UTM Medium')
df['geo_country'].value_counts().head(10).plot(kind='bar', ax=axes[2], title='Geo Country')

plt.tight_layout()
plt.show()

# %% [markdown]
# Сильно преобладает устройство мобильный телефон.
# Компания предпочитает канал привлечения в виде баннера.
# География пользователей преимущественно Россия, что логично для российской компании

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

df['visit_number'].hist(bins=50, ax=axes[0])
axes[0].set_title('Распределение visit_number')

df['target'].value_counts().plot(kind='bar', ax=axes[1])
axes[1].set_title('Баланс классов (target)')

plt.tight_layout()
plt.show()

# %% [markdown]
# Большинство пользователей новые. Очевидный дизбаланс классов это может плохо сказаться на модели, буду использовать в будущем class_weight='balanced'

# %% [markdown]
# ### Feature Engineering

# %%
df.columns.tolist()
# Out:
# ['session_id',
#  'client_id',
#  'visit_date',
#  'visit_time',
#  'visit_number',
#  'utm_source',
#  'utm_medium',
#  'utm_campaign',
#  'utm_adcontent',
#  'utm_keyword',
#  'device_category',
#  'device_os',
#  'device_brand',
#  'device_screen_resolution',
#  'device_browser',
#  'geo_country',
#  'geo_city',
#  'target']

# %%
first_visit = df.groupby('client_id')['visit_date'].transform('min')
first_visit_map = df.groupby('client_id')['visit_date'].min()
df['is_new_client'] = (df['visit_date'] == first_visit).astype(int)

# %%
df.is_new_client.unique()
# Out:
# array([1, 0])

# %%
df['visit_date'].dt.year.value_counts()
# Out:
# visit_date
# 2021    1860042
# Name: count, dtype: int64

# %%
df['visit_month'] = df['visit_date'].dt.month
df['visit_day'] = df['visit_date'].dt.day
df['visit_dayofweek'] = df['visit_date'].dt.dayofweek
df['visit_hour'] = pd.to_datetime(df['visit_time'], format='%H:%M:%S').dt.hour

# %%
df = df.drop(columns=['session_id', 'client_id', 'visit_date', 'visit_time'])

# %%
df['is_russia'] = (df['geo_country'] == 'Russia').astype(int)

df['city_group'] = df['geo_city'].apply(
    lambda x: 'moscow' if 'Moscow' in str(x) 
    else 'spb' if 'Saint Petersburg' in str(x) 
    else 'other'
)

# %%
df = df.drop(columns=['geo_country', 'geo_city'])

# %%
df.utm_medium.unique()
# Out:
# array(['banner', 'cpm', 'cpc', 'organic', '(none)', 'referral', 'smm',
#        'stories', 'blogger_channel', 'blogger_stories', 'email', 'app',
#        'vk_smm', 'cpv', 'push', 'partner', 'tg', 'cpa', 'post',
#        'smartbanner', 'info_text', 'outlook', 'clicks', 'landing',
#        'blogger_header', 'qr', '(not set)', 'fb_smm', 'nkp', 'google_cpc',
#        'sms', 'article', 'users_msk', 'static', 'ok_smm', 'cbaafe',
#        'Sbol_catalog', 'landing_interests', 'yandex_cpc', 'web_polka',
#        'linktest', 'sber_app', 'CPM', 'medium', 'tablet', 'promo_sbol',
#        'reach', 'desktop', 'dom_click', 'social', 'catalogue',
#        'main_polka', 'last', 'link', 'qrcodevideo', 'promo_sber'],
#       dtype=object)

# %%
organic = ['organic', 'referral', '(none)']
df['is_organic'] = df['utm_medium'].isin(organic).astype(int)

# %%
social_sources = ['QxAxdyPLuQMEcrdZWdWb', 'MvfHsxITijuriZxsqZqt', 
                  'ISrKoXQCxqqYvAZICvjs', 'IZEXUFLARCUMynmHNBGo', 
                  'PlbkrSYoHuZBWfYjYnfw', 'gVRrcxiDQubJiljoTbGm']
df['is_social'] = df['utm_source'].isin(social_sources).astype(int)

# %%
df.groupby('is_organic')['target'].mean()
# Out:
# is_organic
# 0    0.021945
# 1    0.040360
# Name: target, dtype: float64

# %% [markdown]
# Органический трафик 4.0% конвертируется лучше чем платный трафик 2,2%

# %%
df.groupby('is_social')['target'].mean()
# Out:
# is_social
# 0    0.029192
# 1    0.014663
# Name: target, dtype: float64

# %% [markdown]
# Социальные сети ~1.5% конвертируются хуже чем не социальные сети 2.9%

# %%
df.columns.tolist()
# Out:
# ['visit_number',
#  'utm_source',
#  'utm_medium',
#  'utm_campaign',
#  'utm_adcontent',
#  'utm_keyword',
#  'device_category',
#  'device_os',
#  'device_brand',
#  'device_screen_resolution',
#  'device_browser',
#  'target',
#  'is_new_client',
#  'visit_month',
#  'visit_day',
#  'visit_dayofweek',
#  'visit_hour',
#  'is_russia',
#  'city_group',
#  'is_organic',
#  'is_social']

# %% [markdown]
# ### Подготавливаю данные для OHE

# %%
df['utm_source'].value_counts(normalize=True).cumsum().head(20)
# Out:
# utm_source
# ZpYIoDJMcFzVoPFsHGJL    0.310902
# fDLlAcSmythWSCVMvqvL    0.472497
# kjsLglQLzykiRbcDiGcD    0.615695
# MvfHsxITijuriZxsqZqt    0.715800
# BHcvLfOaCWvWTykYqHVe    0.778336
# bByPQxmDaMXgpHeypKSM    0.833328
# QxAxdyPLuQMEcrdZWdWb    0.860970
# aXQzDWsJuGXeBXexNHjc    0.877718
# jaSOmLICuBzCFqHfBdRg    0.893438
# RmEBuqrriAfAVsLQQmhk    0.908521
# vFcAhRxLfOWKhvxjELkx    0.921646
# PlbkrSYoHuZBWfYjYnfw    0.932825
# hTjLvqNxGggkGnxSCaTm    0.940673
# gDBGzjFKYabGgSPZvrDH    0.947966
# fgymSoTvjKPEgaIJqsiH    0.953140
# geDcueAOghDzHkGMmdOq    0.957807
# ISrKoXQCxqqYvAZICvjs    0.962448
# nSReTmyFtbSjlPrTKoaX    0.966365
# SzZERoLMmrEUEhDaYcyN    0.970036
# eLzNJHzPelJpEyBwMrKo    0.972931
# Name: proportion, dtype: float64

# %% [markdown]
# Топ 20 покрывает 97% значений, делаю вывод что можно оставить только 20 наибольших значений, остальные заменить на other

# %%
top_sources = df['utm_source'].value_counts().head(20).index
df['utm_source'] = df['utm_source'].where(df['utm_source'].isin(top_sources), other='other')

# %%
df['utm_campaign'].value_counts(normalize=True).cumsum().head(20)
# Out:
# utm_campaign
# LTuZkdKfxRGVceoWkVyg    0.249178
# LEoPHuyFvzoNfnzGgfcd    0.423391
# FTjNLDyTrXaWYgZymFkV    0.556377
# not_set                 0.674441
# gecBYcKZCPMcVYdSSzKP    0.746505
# TmThBvoCcwkCZZUWACYq    0.760804
# XHNUiSKKGTEpSAlaVMFQ    0.773988
# okTXSMadDkjvntEHzIjp    0.787166
# SgIUDYUKnyWHVowUOqid    0.799446
# sbJRYgVfvcnqKJNDDYIr    0.810299
# LwJZxKuWmvOhPsaCeRjG    0.819770
# RoDitORHdzGfGhNCyEMy    0.828214
# bxOTvPtyGSdUrbwoXCPO    0.836501
# zxoiLxhuSIFrCeTLQVWZ    0.843151
# bJJuEXRheRIxXEaYIXqM    0.849728
# YCKgTzTDywjcWyQudGch    0.856201
# nSReTmyFtbSjlPrTKoaX    0.862443
# QEejXfOCtOMFLZqIPApp    0.867912
# vRLTQQKAsFQMxbcHGPhu    0.872999
# jvsVVQVKRfBIqBDBuCkq    0.877273
# Name: proportion, dtype: float64

# %%
top_campaigns = df['utm_campaign'].value_counts().head(20).index
df['utm_campaign'] = df['utm_campaign'].where(df['utm_campaign'].isin(top_campaigns), other='other')

# %%
df['utm_keyword'].value_counts(normalize=True).cumsum().head(20)
# Out:
# utm_keyword
# not_set                 0.581740
# puhZPIYqKXeFPaUviSjo    0.854217
# aXQzDWsJuGXeBXexNHjc    0.867250
# pHqgLcdBQPSLcrTpLkdr    0.874651
# ITfrGJNwVsHBGJMAKoct    0.881830
# hAmNSZmQkKQKAjZEGlgb    0.887904
# UKNBOHebRIIsQRsjNKay    0.893788
# IGUCNvHlhfHpROGclCit    0.897857
# RkpOyeEPgcMBSDuHLQcj    0.901609
# JajANoFxoqXfKRNBUhzx    0.905242
# BmOOOIoWGHEfxEfoUezs    0.908791
# ZNhSIPchlbnKwZWcsKzz    0.911835
# pucKZkLDtpMDBTobJAJG    0.914733
# RrhnkuoaqckNtJpAZDzH    0.917423
# YQXPpoLsxnykCWKhGEmI    0.920044
# DBHgBJHOdbPwsRDUbEgX    0.922448
# tVtbIKrPSOvrXLCznVVe    0.924443
# XEayFbemrPYbxFeNbxif    0.926430
# MWLEpQPyjGkjHseVyeyQ    0.928126
# fzbotReoFzSuckjwcpCs    0.929720
# Name: proportion, dtype: float64

# %%
df.groupby('utm_keyword').agg(
    count=('target', 'count'),
    cr=('target', 'mean')
).query('count >= 100').sort_values('cr', ascending=False)
# Out:
#                       count        cr
# utm_keyword
# JTBldRAXvttfVmCNgppl    980  0.136735
# UbQpozKfTgYxQovHjkQM    314  0.121019
# mIKayglJaKQZvgdtLfqT    921  0.111835
# xkXwwebfDFpZOOKBcXpE   1212  0.079208
# sKuhgZXGwZSwSoGyRIEH    122  0.065574
# ...                     ...       ...
# EFePHapVShTKxBNclrhX    123  0.000000
# qKtZDknwokiQQjEGIkQU    105  0.000000
# jHeivNstnTyIeSIoRaQA    114  0.000000
# qUcotcWimEOQiboVPcCx   2385  0.000000
# iYCvLHKtSHnVUTFbZVoL    629  0.000000
#
# [221 rows x 2 columns]

# %%
top_keywords = df['utm_keyword'].value_counts().head(20).index
df['utm_keyword'] = df['utm_keyword'].where(df['utm_keyword'].isin(top_keywords), other='other')

# %%
df.columns.tolist()
# Out:
# ['visit_number',
#  'utm_source',
#  'utm_medium',
#  'utm_campaign',
#  'utm_adcontent',
#  'utm_keyword',
#  'device_category',
#  'device_os',
#  'device_brand',
#  'device_screen_resolution',
#  'device_browser',
#  'target',
#  'is_new_client',
#  'visit_month',
#  'visit_day',
#  'visit_dayofweek',
#  'visit_hour',
#  'is_russia',
#  'city_group',
#  'is_organic',
#  'is_social']

# %%
df.select_dtypes('object').nunique().sort_values()
# Out:
# device_category                3
# city_group                     3
# device_os                     14
# utm_source                    21
# utm_campaign                  21
# utm_keyword                   21
# utm_medium                    56
# device_browser                57
# device_brand                 206
# utm_adcontent                287
# device_screen_resolution    5039
# dtype: int64

# %%
df['device_screen_resolution'] = df['device_screen_resolution'].replace('(not set)', '0x0')

df['screen_width'] = df['device_screen_resolution'].str.split('x').str[0].astype(int)
df['screen_height'] = df['device_screen_resolution'].str.split('x').str[1].astype(int)
df = df.drop(columns=['device_screen_resolution'])

# %%
# Заменяем 0 на NaN чтобы не учитывать при расчёте моды
df['screen_width'] = df['screen_width'].replace(0, np.nan)
df['screen_height'] = df['screen_height'].replace(0, np.nan)


# Заполняем модой по device_category
for col in ['screen_width', 'screen_height']:
    mode_map = df.groupby('device_category')[col].agg(lambda x: x.mode()[0])
    df[col] = df.apply(
        lambda row: mode_map[row['device_category']] 
        if pd.isna(row[col]) else row[col], axis=1
    )

# %%
screen_mode_map = {}
for col in ['screen_width', 'screen_height']:
    screen_mode_map[col] = df.groupby('device_category')[col].agg(lambda x: x.mode()[0])

# %%
df['screen_width'].describe()
# Out:
# count    1.860042e+06
# mean     4.173024e+02
# std      6.576933e+01
# min      2.580000e+02
# 25%      3.600000e+02
# 50%      3.930000e+02
# 75%      4.280000e+02
# max      5.300000e+02
# Name: screen_width, dtype: float64

# %%
df['screen_height'].describe()
# Out:
# count    1.860042e+06
# mean     8.336093e+02
# std      1.277458e+02
# min      5.560000e+02
# 25%      7.600000e+02
# 50%      8.440000e+02
# 75%      8.960000e+02
# max      1.100000e+03
# Name: screen_height, dtype: float64

# %%
q_25_sw = df['screen_width'].quantile(0.25)
q_75_sw = df['screen_width'].quantile(0.75)
q_25_sh = df['screen_height'].quantile(0.25)
q_75_sh = df['screen_height'].quantile(0.75)



for col in ['screen_width', 'screen_height']:
    q_25 = df[col].quantile(0.25)
    q_75 = df[col].quantile(0.75)
    iqr = q_75 - q_25
    df[col] = df[col].clip(lower=q_25 - 1.5*iqr, upper=q_75 + 1.5*iqr)

# %%
df['screen_width'].describe()
# Out:
# count    1.860042e+06
# mean     4.173024e+02
# std      6.576933e+01
# min      2.580000e+02
# 25%      3.600000e+02
# 50%      3.930000e+02
# 75%      4.280000e+02
# max      5.300000e+02
# Name: screen_width, dtype: float64

# %%
df['screen_height'].describe()
# Out:
# count    1.860042e+06
# mean     8.336093e+02
# std      1.277458e+02
# min      5.560000e+02
# 25%      7.600000e+02
# 50%      8.440000e+02
# 75%      8.960000e+02
# max      1.100000e+03
# Name: screen_height, dtype: float64

# %%
df['utm_adcontent'].value_counts(normalize=True).cumsum().head(20)
# Out:
# utm_adcontent
# JNHcPlZPxEMWDnRiyoBf    0.541170
# not_set                 0.721604
# vCIpmpaGBnIQhyYNkXqp    0.818940
# xhoenQgDQsgfEPYNPwKO    0.879730
# PkybGvWbaqORmxjNunqZ    0.912157
# LLfCasrxQzJIyuldcuWy    0.925179
# TuyPWsGQruPMpKvRxeBF    0.934958
# UxrnyMlRBSOhOjytXnMG    0.942260
# dUuXlWzvmhDSyclWRhNP    0.947787
# yYdBRbPmBMUZHXwqGxNx    0.953002
# WYLajZgbUhGimwBKDZUH    0.957631
# SOkCdPxfUcZUzzOdgGES    0.961566
# AdeErYgVTbRcAWtHrMHq    0.965002
# nNqUcgFgcqQbTVSvgaHr    0.968331
# aYAcKhelKzYpXrRYknSP    0.971067
# XSkXBCPfnJjvxbfeewtd    0.973424
# XKsYZiUFcdkUXQpoLKyS    0.975634
# FkiRXDLOWtzVfvhEkhNo    0.977162
# xnyHaukLtAvgViiZSyBC    0.978550
# SAVVWaMghGnnvPOqMOIt    0.979895
# Name: proportion, dtype: float64

# %%
top_adcontent = df['utm_adcontent'].value_counts().head(20).index
df['utm_adcontent'] = df['utm_adcontent'].where(df['utm_adcontent'].isin(top_adcontent), other='other')

# %%
df['device_brand'].value_counts(normalize=True).cumsum().head(20)
# Out:
# device_brand
# Apple        0.296277
# not_set      0.493680
# Samsung      0.672275
# Xiaomi       0.827308
# Huawei       0.927226
# Realme       0.937472
# (not set)    0.946905
# OPPO         0.954165
# Vivo         0.960477
# OnePlus      0.965834
# Asus         0.970097
# Nokia        0.974013
# Sony         0.977486
# ZTE          0.980908
# Google       0.983677
# Meizu        0.985693
# Lenovo       0.987385
# Blackview    0.988869
# Tecno        0.990295
# LG           0.991611
# Name: proportion, dtype: float64

# %%
top_brands = df['device_brand'].value_counts().head(20).index
df['device_brand'] = df['device_brand'].where(df['device_brand'].isin(top_brands), other='other')

# %%
df['utm_medium'].value_counts(normalize=True).cumsum().head(20)
# Out:
# utm_medium
# banner             0.296914
# cpc                0.530669
# (none)             0.692264
# cpm                0.822414
# referral           0.904159
# organic            0.938048
# email              0.953768
# push               0.968840
# stories            0.974529
# cpv                0.978842
# blogger_channel    0.983151
# smartbanner        0.986804
# blogger_stories    0.989122
# cpa                0.991422
# tg                 0.993579
# app                0.995103
# post               0.996354
# smm                0.997421
# outlook            0.998137
# clicks             0.998639
# Name: proportion, dtype: float64

# %%
top_medium = df['utm_medium'].value_counts().head(20).index
df['utm_medium'] = df['utm_medium'].where(df['utm_medium'].isin(top_medium), other='other')

# %%
df['device_browser'].value_counts(normalize=True).cumsum().head(20)
# Out:
# device_browser
# Chrome                              0.544846
# Safari                              0.802131
# YaBrowser                           0.873802
# Safari (in-app)                     0.911389
# Android Webview                     0.941156
# Samsung Internet                    0.966591
# Opera                               0.981008
# Firefox                             0.989926
# Edge                                0.998563
# UC Browser                          0.999031
# Android Runtime                     0.999242
# Mozilla Compatible Agent            0.999437
# [FBAN                               0.999581
# Instagram 208.0.0.32.135 Android    0.999656
# Instagram 209.0.0.21.119 Android    0.999716
# MRCHROME                            0.999758
# Android Browser                     0.999784
# Opera Mini                          0.999808
# Puffin                              0.999832
# Internet Explorer                   0.999852
# Name: proportion, dtype: float64

# %%
top_browsers = df['device_browser'].value_counts().head(20).index
df['device_browser'] = df['device_browser'].where(df['device_browser'].isin(top_browsers), other='other')

# %%
df.select_dtypes('object').nunique().sort_values()
# Out:
# device_category     3
# city_group          3
# device_os          14
# utm_source         21
# utm_medium         21
# utm_campaign       21
# utm_adcontent      21
# utm_keyword        21
# device_brand       21
# device_browser     21
# dtype: int64

# %% [markdown]
# # Save Prepared DS

# %%
df.to_csv('data/df_prepared.csv', index=False)

# %%
df.columns.tolist()
# Out:
# ['visit_number',
#  'utm_source',
#  'utm_medium',
#  'utm_campaign',
#  'utm_adcontent',
#  'utm_keyword',
#  'device_category',
#  'device_os',
#  'device_brand',
#  'device_browser',
#  'target',
#  'is_new_client',
#  'visit_month',
#  'visit_day',
#  'visit_dayofweek',
#  'visit_hour',
#  'is_russia',
#  'city_group',
#  'is_organic',
#  'is_social',
#  'screen_width',
#  'screen_height']

# %% [markdown]
# # Modeling

# %%
models = {
    'LogisticRegression': LogisticRegression(class_weight='balanced', max_iter=1000),
    'RandomForest': RandomForestClassifier(class_weight='balanced', random_state=42, n_jobs=-1),
    'MLP': MLPClassifier(hidden_layer_sizes=(256, 128, 64),
                         random_state=42,
                         max_iter=500)
        }

# %%
X = df.drop(columns=['target'])
y = df['target']

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y
)

cat_cols = X.select_dtypes('object').columns.tolist()
num_cols = X.select_dtypes('number').columns.tolist()

# %%
preprocessor = ColumnTransformer([
    ('num', StandardScaler(), num_cols),
    ('cat', OneHotEncoder(handle_unknown='ignore', sparse_output=False), cat_cols)
])

# %%
X_sample, _, y_sample, _ = train_test_split(
    X_train, y_train, train_size=0.2, random_state=42, stratify=y_train
)

# %%
best_pipe = None
best_score = 0.0

for name, model in models.items():
    pipe = Pipeline([
        ('preprocessor', preprocessor),
        ('model', model)
    ])
    pipe.fit(X_sample, y_sample)
    y_pred = pipe.predict_proba(X_test)[:, 1]
    auc = roc_auc_score(y_test, y_pred)
    print(f'{name}: ROC-AUC = {auc:.4f}')
    
    if auc > best_score:
        best_score = auc
        best_pipe = pipe
# Out:
# LogisticRegression: ROC-AUC = 0.6812
# RandomForest: ROC-AUC = 0.6191
# MLP: ROC-AUC = 0.5845

# %%
# Дообучаем на всех данных
best_pipe.fit(X, y)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['visit_number',
#                                                    'is_new_client',
#                                                    'visit_month', 'visit_day',
#                                                    'visit_dayofweek',
#                                                    'visit_hour', 'is_russia',
#                                                    'is_organic', 'is_social',
#                                                    'screen_width',
#                                                    'screen_height']),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False),
# ...

# %%
artifacts = {
    'model': best_pipe,
    'os_map': os_map,
    'boundaries': {
        'visit_number': (q_25_vn, q_75_vn),
        'screen_width': (q_25_sw, q_75_sw),
        'screen_height': (q_25_sh, q_75_sh)
    },
    'first_visit_map': first_visit_map,
    'screen_mode_map': screen_mode_map,
    'top_categories': {
        'utm_source': top_sources,
        'utm_campaign': top_campaigns,
        'utm_keyword': top_keywords,
        'utm_adcontent': top_adcontent,
        'utm_medium': top_medium,
        'device_brand': top_brands,
        'device_browser': top_browsers
    }
}

# %%
with open('model/sber_auto_model.pkl', 'wb') as f:
    dill.dump(artifacts, f)

# %%
# Получаем названия фичей после OHE
feature_names = best_pipe.named_steps['preprocessor'].get_feature_names_out()
coefficients = best_pipe.named_steps['model'].coef_[0]

# Создаём датафрейм и сортируем по абсолютному значению
feat_importance = pd.DataFrame({
    'feature': feature_names, 
    'coefficient': coefficients
}).assign(abs_coef=lambda x: x['coefficient'].abs())\
  .sort_values('abs_coef', ascending=False).head(20)

# Визуализируем
plt.figure(figsize=(10, 8))
plt.barh(feat_importance['feature'], feat_importance['coefficient'])
plt.title('Важность признаков (коэффициенты LogReg)')
plt.tight_layout()
plt.show()

# %% [markdown]
# несмотря на то что названия зашифрованы, конкретные источники и рекламные материалы сильно влияют на вероятность целевого действия. Это говорит о том что качество рекламного контента важнее канала привлечения.

# %%
dummy = Pipeline([
    ('preprocessor', preprocessor),
    ('model', DummyClassifier(strategy='most_frequent'))
])
dummy.fit(X_train, y_train)
y_dummy = dummy.predict_proba(X_test)[:, 1]
print(f'Baseline ROC-AUC: {roc_auc_score(y_test, y_dummy):.4f}')
print(f'LogReg ROC-AUC: {best_score:.4f}')
# Out:
# Baseline ROC-AUC: 0.5000
# LogReg ROC-AUC: 0.6812

# %% [markdown]
# Логистическая регрессия показала ROC-AUC = 0.68 против бейслайна 0.50, превысив цель в 0.65. Модель сильно лучше случайного предсказания.
